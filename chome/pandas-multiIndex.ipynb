# %% [markdown]
# 階層型インデックス

# %%
import pandas as pd
import numpy as np

# %%
index = [('California', 2000), ('California', 2010),
         ('New York', 2000), ('New York', 2010),
         ('Texas', 2000), ('Texas', 2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %%
#スライス
pop[('California', 2010):('Texas', 2000)]
# Out:
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# dtype: int64

# %%
#2010年を全部選択するのはめんどい
pop[[i for i in pop.index if i[1] == 2010]]
# Out:
# (California, 2010)    37253956
# (New York, 2010)      19378102
# (Texas, 2010)         25145561
# dtype: int64

# %% [markdown]
# マルチインデックス
# →複数の値をインデックスにする
# →複数の値を特定すれば値が一意に定まるときに使う

# %%
#マルチインデックス作成
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )

# %%
#インデックスを再設定
pop = pop.reindex(index)
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
#2010年のデータを簡単に指定できる
pop[:, 2010]
# Out:
# California    37253956
# New York      19378102
# Texas         25145561
# dtype: int64

# %% [markdown]
# データ整形

# %%
pop_df = pop.unstack()
pop_df
# Out:
#                 2000      2010
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop_df.stack()
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
#3次元にも応用可
#列を追加するみたいに次元を追加できる
pop_df = pd.DataFrame({'total': pop,
                       'under18': [9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})
pop_df
# Out:
#                     total  under18
# California 2000  33871648  9267089
#            2010  37253956  9284094
# New York   2000  18976457  4687374
#            2010  19378102  4318033
# Texas      2000  20851820  5906301
#            2010  25145561  6879014

# %%
f_u18 = pop_df['under18'] / pop_df['total']
f_u18.unstack()
# Out:
#                 2000      2010
# California  0.273594  0.249211
# New York    0.247010  0.222831
# Texas       0.283251  0.273568

# %% [markdown]
# マルチインデックスの作成方法

# %%
#インデックスに複数の配列を渡してやる
df = pd.DataFrame(np.random.rand(4, 2),
                  index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                  columns=['data1', 'data2'])
df
# Out:
#         data1     data2
# a 1  0.263971  0.867044
#   2  0.294477  0.780552
# b 1  0.735685  0.335842
#   2  0.839785  0.325558

# %%
#辞書で複数のインデックスを指定してもいい
data = {('California', 2000): 33871648,
        ('California', 2010): 37253956,
        ('Texas', 2000): 20851820,
        ('Texas', 2010): 25145561,
        ('New York', 2000): 18976457,
        ('New York', 2010): 19378102}
pd.Series(data)
# Out:
# California  2000    33871648
#             2010    37253956
# Texas       2000    20851820
#             2010    25145561
# New York    2000    18976457
#             2010    19378102
# dtype: int64

# %% [markdown]
# MutiIndexの使い方

# %%
pd.MultiIndex.from_arrays([['a', 'a', 'b', 'b'], [1, 2, 1, 2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2)])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
#配列の組み合わせから
pd.MultiIndex.from_product([['a', 'b'], [1, 2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
#直接指定
#テキストがミス:labels→codes
pd.MultiIndex(levels=[['a', 'b'], [1, 2]],
              codes=[[0, 0, 1, 1], [0, 1, 0, 1]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %% [markdown]
# レベル名

# %%
pop.index.names = ['state', 'year']
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# 列名の複数指定

# %%
#マルチインデックス(index、columns)
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]],
                                   names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']],
                                     names=['subject', 'type'])

#データを入れる
data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10
data += 37

health_data = pd.DataFrame(data, index=index, columns=columns)
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      37.0  36.8  37.0  36.1  49.0  37.8
#      2      30.0  36.1  27.0  38.8  50.0  38.6
# 2014 1      37.0  38.6  41.0  36.5  29.0  37.0
#      2      11.0  35.5  31.0  36.2  39.0  35.9

# %%
health_data['Guido']
# Out:
# type          HR  Temp
# year visit
# 2013 1      37.0  36.1
#      2      27.0  38.8
# 2014 1      41.0  36.5
#      2      31.0  36.2

# %% [markdown]
# マルチインデックスのスライス

# %%
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop['California', 2000]
# Out:
# 33871648

# %%
pop['California']
# Out:
# year
# 2000    33871648
# 2010    37253956
# dtype: int64

# %%
pop.loc['California':'New York']
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# dtype: int64

# %%
pop[:, 2000]
# Out:
# state
# California    33871648
# New York      18976457
# Texas         20851820
# dtype: int64

# %%
pop[pop > 22000000]
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# Texas       2010    25145561
# dtype: int64

# %%
#ファンシーインデックス
pop[['California', 'Texas']]
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# 複数のレベルのインデックス指定

# %%
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      37.0  36.8  37.0  36.1  49.0  37.8
#      2      30.0  36.1  27.0  38.8  50.0  38.6
# 2014 1      37.0  38.6  41.0  36.5  29.0  37.0
#      2      11.0  35.5  31.0  36.2  39.0  35.9

# %%
health_data['Guido', 'HR']
# Out:
# year  visit
# 2013  1        37.0
#       2        27.0
# 2014  1        41.0
#       2        31.0
# Name: (Guido, HR), dtype: float64

# %%
health_data.iloc[:2, :2]
# Out:
# subject      Bob
# type          HR  Temp
# year visit
# 2013 1      37.0  36.8
#      2      30.0  36.1

# %%
health_data.loc[:, ('Bob', 'HR')]
# Out:
# year  visit
# 2013  1        37.0
#       2        30.0
# 2014  1        37.0
#       2        11.0
# Name: (Bob, HR), dtype: float64

# %%
#インデックスのスライスはできない
health_data.loc[(:, 1), (:, 'HR')]
# Out:
#   File "<ipython-input-36-d3b1495e95e2>", line 2
#     health_data.loc[(:, 1), (:, 'HR')]
#                      ^
# SyntaxError: invalid syntax

# %%
#インデックスのスライスしたい場合はIndexSliceを使う
idx = pd.IndexSlice
health_data.loc[idx[:, 1], idx[:, 'HR']]
# Out:
# subject      Bob Guido   Sue
# type          HR    HR    HR
# year visit
# 2013 1      37.0  37.0  49.0
# 2014 1      37.0  41.0  29.0

# %% [markdown]
# インデックスの並び替え

# %%
#ソートされていないインデックス
index = pd.MultiIndex.from_product([['a', 'c', 'b'], [1, 2]])
data = pd.Series(np.random.rand(6), index=index)
data.index.names = ['char', 'int']
data
# Out:
# char  int
# a     1      0.846359
#       2      0.276109
# c     1      0.145870
#       2      0.256390
# b     1      0.853377
#       2      0.484729
# dtype: float64

# %%
try:
    data['a':'b']
except KeyError as e:
    print(type(e))
    print(e)
# Out:
# <class 'pandas.errors.UnsortedIndexError'>
# 'Key length (1) was greater than MultiIndex lexsort depth (0)'

# %%
#インデックスのソート
data = data.sort_index()
data
# Out:
# char  int
# a     1      0.846359
#       2      0.276109
# b     1      0.853377
#       2      0.484729
# c     1      0.145870
#       2      0.256390
# dtype: float64

# %%
data['a':'b']
# Out:
# char  int
# a     1      0.846359
#       2      0.276109
# b     1      0.853377
#       2      0.484729
# dtype: float64

# %% [markdown]
# スタックとアンスタック

# %%
#インデックスのレベルを指定できる
pop.unstack(level=0)
# Out:
# state  California  New York     Texas
# year
# 2000     33871648  18976457  20851820
# 2010     37253956  19378102  25145561

# %%
pop.unstack(level=1)
# Out:
# year            2000      2010
# state
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop.unstack().stack()
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# インデックスの再設定

# %%
pop_flat = pop.reset_index(name='population')
pop_flat
# Out:
#         state  year  population
# 0  California  2000    33871648
# 1  California  2010    37253956
# 2    New York  2000    18976457
# 3    New York  2010    19378102
# 4       Texas  2000    20851820
# 5       Texas  2010    25145561

# %%
pop_flat.set_index(['state', 'year'])
# Out:
#                  population
# state      year
# California 2000    33871648
#            2010    37253956
# New York   2000    18976457
#            2010    19378102
# Texas      2000    20851820
#            2010    25145561

# %% [markdown]
# データ操作
# mean(),sum(),max()

# %%
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      37.0  36.8  37.0  36.1  49.0  37.8
#      2      30.0  36.1  27.0  38.8  50.0  38.6
# 2014 1      37.0  38.6  41.0  36.5  29.0  37.0
#      2      11.0  35.5  31.0  36.2  39.0  35.9

# %%
data_mean = health_data.mean(level='year')
data_mean
# Out:
# subject   Bob        Guido          Sue
# type       HR   Temp    HR   Temp    HR   Temp
# year
# 2013     33.5  36.45  32.0  37.45  49.5  38.20
# 2014     24.0  37.05  36.0  36.35  34.0  36.45

# %%
data_mean.mean(axis=1, level='type')
# Out:
# type         HR       Temp
# year
# 2013  38.333333  37.366667
# 2014  31.333333  36.616667
