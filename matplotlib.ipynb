# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")
import numpy as np

# %%
x = np.linspace(0,10,30)
x
# Out:
# array([ 0.        ,  0.34482759,  0.68965517,  1.03448276,  1.37931034,
#         1.72413793,  2.06896552,  2.4137931 ,  2.75862069,  3.10344828,
#         3.44827586,  3.79310345,  4.13793103,  4.48275862,  4.82758621,
#         5.17241379,  5.51724138,  5.86206897,  6.20689655,  6.55172414,
#         6.89655172,  7.24137931,  7.5862069 ,  7.93103448,  8.27586207,
#         8.62068966,  8.96551724,  9.31034483,  9.65517241, 10.        ])

# %%
y = np.sin(x)

# %%
plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x,y,"-ok")

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt = ".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def f(x,y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0,5,50)
y = np.linspace(0,5,40)

# %%
X,Y = np.meshgrid(x,y)
Z = f(X,Y)

# %%
plt.contour(X,Y,Z,colors = "black")

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  3.,  16.,  63., 137., 238., 272., 179.,  75.,  12.,   5.]),
#  array([-3.43582058, -2.75834023, -2.08085988, -1.40337952, -0.72589917,
#         -0.04841882,  0.62906153,  1.30654189,  1.98402224,  2.66150259,
#          3.33898295]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data,bins=30,normed=True,alpha=0.5,histtype="stepfilled",color="steelblue",edgecolor="none")
# Out:
# C:\Users\kouta\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.00442817, 0.        , 0.00885635, 0.00442817, 0.02656904,
#         0.03985355, 0.05756625, 0.11513249, 0.10627614, 0.11070432,
#         0.26126219, 0.23469315, 0.34982564, 0.34982564, 0.35425382,
#         0.46938631, 0.35425382, 0.38082285, 0.32325661, 0.23026498,
#         0.23912133, 0.15941422, 0.11070432, 0.06199442, 0.02214086,
#         0.02656904, 0.00442817, 0.01328452, 0.00442817, 0.00442817]),
#  array([-3.43582058, -3.2099938 , -2.98416702, -2.75834023, -2.53251345,
#         -2.30668666, -2.08085988, -1.85503309, -1.62920631, -1.40337952,
#         -1.17755274, -0.95172596, -0.72589917, -0.50007239, -0.2742456 ,
#         -0.04841882,  0.17740797,  0.40323475,  0.62906153,  0.85488832,
#          1.0807151 ,  1.30654189,  1.53236867,  1.75819546,  1.98402224,
#          2.20984903,  2.43567581,  2.66150259,  2.88732938,  3.11315616,
#          3.33898295]),
#  <a list of 1 Patch objects>)

# %%
mean = [0,0]
cov = [[1,1],[1,2]]
x,y = np.random.multivariate_normal(mean,cov,10000).T

# %%
plt.hist2d(x,y,bins=30,cmap="Blues")
cb = plt.colorbar()
cb.set_label("counts in bin")
